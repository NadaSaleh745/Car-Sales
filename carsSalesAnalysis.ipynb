# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\nada saleh\Downloads\Dataset_Car.csv", encoding='ISO-8859-1')

# %%
df
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# 0        Bulgaria       0  41.851720    62812.09301      11609.380910
# 1          Belize       0  40.870623    66646.89292       9572.957136
# 2         Algeria       1  43.152897    53798.55112      11160.355060
# 3    Cook Islands       1  58.271369    79370.03798      14426.164850
# 4          Brazil       1  57.313749    59729.15130       5358.712177
# ..            ...     ...        ...            ...               ...
# 495         Nepal       0  41.462515    71942.40291       6995.902524
# 496      Zimbabwe       1  37.642000    56039.49793      12301.456790
# 497   Philippines       1  53.943497    68888.77805      10611.606860
# 498      Botswana       1  59.160509    49811.99062      14013.034510
# 499        marlal       1  46.731152    61370.67766       9391.341628
#
#        net worth  car purchase amount
# 0    238961.2505          35321.45877
# 1    530973.9078          45115.52566
# 2    638467.1773          42925.70921
# 3    548599.0524          67422.36313
# 4    560304.0671          55915.46248
# ..           ...                  ...
# 495  541670.1016          48901.44342
# 496  360419.0988          31491.41457
# 497  764531.3203          64147.28888
# 498  337826.6382          45442.15353
# 499  462946.4924          45107.22566
#
# [500 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer name        500 non-null    object
#  1   customer e-mail      500 non-null    object
#  2   country              500 non-null    object
#  3   gender               500 non-null    int64
#  4   age                  500 non-null    float64
#  5   annual Salary        500 non-null    float64
#  6   credit card debt     500 non-null    float64
#  7   net worth            500 non-null    float64
#  8   car purchase amount  500 non-null    float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 35.3+ KB

# %%
df['car purchase amount'].plot(kind='box')
plt.show()

# %%
plt.scatter(df['car purchase amount'], df['age'], label='Age', marker='o')
plt.xlabel('Car Purchase Amount')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
plt.scatter(df['car purchase amount'], df['annual Salary'], label='Annual salary', marker='o')
plt.xlabel('Car Purchase Amount')
plt.ylabel('Annual Salary')
# Out:
# Text(0, 0.5, 'Annual Salary')

# %%
plt.scatter(df['car purchase amount'], df['net worth'], label='Net worth', marker='o')
plt.xlabel('Car Purchase Amount')
plt.ylabel('Net Worth')
# Out:
# Text(0, 0.5, 'Net Worth')

# %%
labels = ['Male', 'Female']
plt.pie(df['gender'].value_counts(), labels=labels, autopct='%1.1f%%')
plt.show()

# %%
sales = df['country'].value_counts()

# %%
sales
# Out:
# country
# Mauritania                                      6
# Israel                                          6
# Bolivia                                         6
# Kyrgyzstan                                      5
# Samoa                                           5
#                                                ..
# Ukraine                                         1
# New Zealand                                     1
# Saint Helena, Ascension and Tristan da Cunha    1
# Malaysia                                        1
# marlal                                          1
# Name: count, Length: 211, dtype: int64

# %%
countriesCorrected = {
    "Palestine, State of": "Palestine",
    "Virgin Islands, British": "British Virgin Islands",
    "Virgin Islands, United States": "United States Virgin Islands",
    "Korea, South": "South Korea",
    "Saint Helena, Ascension and Tristan da Cunha": "Saint Helena, Ascension and Tristan da Cunha",
    "Bonaire, Sint Eustatius and Saba": "Bonaire, Sint Eustatius and Saba",
    "Isle of Man": "Isle of Man",
    "Tokelau": "Tokelau",
    "Bouvet Island": "Bouvet Island",
    "Guernsey": "Guernsey",
    "Western Sahara": "Western Sahara",
    "Niue": "Niue",
    "Cocos (Keeling) Islands": "Cocos (Keeling) Islands",
    "Saint Barthélemy": "Saint Barthélemy",
    "Mayotte": "Mayotte"
}
df['country'] = df['country'].replace(countriesCorrected)

# %%
df
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# 0        Bulgaria       0  41.851720    62812.09301      11609.380910
# 1          Belize       0  40.870623    66646.89292       9572.957136
# 2         Algeria       1  43.152897    53798.55112      11160.355060
# 3    Cook Islands       1  58.271369    79370.03798      14426.164850
# 4          Brazil       1  57.313749    59729.15130       5358.712177
# ..            ...     ...        ...            ...               ...
# 495         Nepal       0  41.462515    71942.40291       6995.902524
# 496      Zimbabwe       1  37.642000    56039.49793      12301.456790
# 497   Philippines       1  53.943497    68888.77805      10611.606860
# 498      Botswana       1  59.160509    49811.99062      14013.034510
# 499        marlal       1  46.731152    61370.67766       9391.341628
#
#        net worth  car purchase amount
# 0    238961.2505          35321.45877
# 1    530973.9078          45115.52566
# 2    638467.1773          42925.70921
# 3    548599.0524          67422.36313
# 4    560304.0671          55915.46248
# ..           ...                  ...
# 495  541670.1016          48901.44342
# 496  360419.0988          31491.41457
# 497  764531.3203          64147.28888
# 498  337826.6382          45442.15353
# 499  462946.4924          45107.22566
#
# [500 rows x 9 columns]

# %%
from pycountry_convert import country_alpha2_to_continent_code, country_name_to_country_alpha2
def get_continent(col):
    try:
        cn_a2_code =  country_name_to_country_alpha2(col)
    except:
        cn_a2_code = 'Unknown' 
    try:
        cn_continent = country_alpha2_to_continent_code(cn_a2_code)
    except:
        cn_continent = 'Unknown' 
    return pd.Series([cn_a2_code, cn_continent])

df[['country_code', 'continent']] = df['country'].apply(get_continent)

# %%
df
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# 0        Bulgaria       0  41.851720    62812.09301      11609.380910
# 1          Belize       0  40.870623    66646.89292       9572.957136
# 2         Algeria       1  43.152897    53798.55112      11160.355060
# 3    Cook Islands       1  58.271369    79370.03798      14426.164850
# 4          Brazil       1  57.313749    59729.15130       5358.712177
# ..            ...     ...        ...            ...               ...
# 495         Nepal       0  41.462515    71942.40291       6995.902524
# 496      Zimbabwe       1  37.642000    56039.49793      12301.456790
# 497   Philippines       1  53.943497    68888.77805      10611.606860
# 498      Botswana       1  59.160509    49811.99062      14013.034510
# 499        marlal       1  46.731152    61370.67766       9391.341628
#
#        net worth  car purchase amount country_code continent
# 0    238961.2505          35321.45877           BG        EU
# 1    530973.9078          45115.52566           BZ        NA
# 2    638467.1773          42925.70921           DZ        AF
# 3    548599.0524          67422.36313           CK        OC
# 4    560304.0671          55915.46248           BR        SA
# ..           ...                  ...          ...       ...
# 495  541670.1016          48901.44342           NP        AS
# 496  360419.0988          31491.41457           ZW        AF
# 497  764531.3203          64147.28888           PH        AS
# 498  337826.6382          45442.15353           BW        AF
# 499  462946.4924          45107.22566      Unknown   Unknown
#
# [500 rows x 11 columns]

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="nadasaleh745@myserver.com", timeout=10)

def get_lat_lon(country_code):
    location = geolocator.geocode(country_code)
    if location:
        return location.latitude, location.longitude
    else:
        return None, None

# %%
df['Coordinates'] = df['country_code'].apply(lambda x: get_lat_lon(x))
df[['Latitude', 'Longitude']] = pd.DataFrame(df['Coordinates'].tolist(), index=df.index)

# %%
df
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# 0        Bulgaria       0  41.851720    62812.09301      11609.380910
# 1          Belize       0  40.870623    66646.89292       9572.957136
# 2         Algeria       1  43.152897    53798.55112      11160.355060
# 3    Cook Islands       1  58.271369    79370.03798      14426.164850
# 4          Brazil       1  57.313749    59729.15130       5358.712177
# ..            ...     ...        ...            ...               ...
# 495         Nepal       0  41.462515    71942.40291       6995.902524
# 496      Zimbabwe       1  37.642000    56039.49793      12301.456790
# 497   Philippines       1  53.943497    68888.77805      10611.606860
# 498      Botswana       1  59.160509    49811.99062      14013.034510
# 499        marlal       1  46.731152    61370.67766       9391.341628
#
#        net worth  car purchase amount country_code continent  \
# 0    238961.2505          35321.45877           BG        EU
# 1    530973.9078          45115.52566           BZ        NA
# 2    638467.1773          42925.70921           DZ        AF
# 3    548599.0524          67422.36313           CK        OC
# 4    560304.0671          55915.46248           BR        SA
# ..           ...                  ...          ...       ...
# 495  541670.1016          48901.44342           NP        AS
# 496  360419.0988          31491.41457           ZW        AF
# 497  764531.3203          64147.28888           PH        AS
# 498  337826.6382          45442.15353           BW        AF
# 499  462946.4924          45107.22566      Unknown   Unknown
#
#                              Coordinates   Latitude   Longitude
# 0               (42.6073975, 25.4856617)  42.607397   25.485662
# 1              (17.1204943, -88.6859028)  17.120494  -88.685903
# 2                (28.0000272, 2.9999825)  28.000027    2.999983
# 3    (-19.99697155, -157.78587140620786) -19.996972 -157.785871
# 4                   (-10.3333333, -53.2) -10.333333  -53.200000
# ..                                   ...        ...         ...
# 495             (28.3780464, 83.9999901)  28.378046   83.999990
# 496            (-18.4554963, 29.7468414) -18.455496   29.746841
# 497            (12.7503486, 122.7312101)  12.750349  122.731210
# 498            (-23.1681782, 24.5928742) -23.168178   24.592874
# 499     (26.49253305, 92.33087891709363)  26.492533   92.330879
#
# [500 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer name        500 non-null    object
#  1   customer e-mail      500 non-null    object
#  2   country              500 non-null    object
#  3   gender               500 non-null    int64
#  4   age                  500 non-null    float64
#  5   annual Salary        500 non-null    float64
#  6   credit card debt     500 non-null    float64
#  7   net worth            500 non-null    float64
#  8   car purchase amount  500 non-null    float64
#  9   country_code         500 non-null    object
#  10  continent            500 non-null    object
#  11  Coordinates          500 non-null    object
#  12  Latitude             500 non-null    float64
#  13  Longitude            500 non-null    float64
# dtypes: float64(7), int64(1), object(6)
# memory usage: 54.8+ KB

# %%
Sales = df['country'].value_counts()
Sales
# Out:
# country
# Mauritania                                      6
# Israel                                          6
# Bolivia                                         6
# Kyrgyzstan                                      5
# Samoa                                           5
#                                                ..
# Ukraine                                         1
# New Zealand                                     1
# Saint Helena, Ascension and Tristan da Cunha    1
# Malaysia                                        1
# marlal                                          1
# Name: count, Length: 211, dtype: int64

# %%
dfMap = df[['country', 'Latitude', 'Longitude']]
dfMap['sales'] = dfMap['country'].map(Sales)
dfMap
# Out:
# C:\Users\nada saleh\AppData\Local\Temp\ipykernel_26524\2263123792.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfMap['sales'] = dfMap['country'].map(Sales)
#           country   Latitude   Longitude  sales
# 0        Bulgaria  42.607397   25.485662      2
# 1          Belize  17.120494  -88.685903      3
# 2         Algeria  28.000027    2.999983      5
# 3    Cook Islands -19.996972 -157.785871      1
# 4          Brazil -10.333333  -53.200000      3
# ..            ...        ...         ...    ...
# 495         Nepal  28.378046   83.999990      3
# 496      Zimbabwe -18.455496   29.746841      2
# 497   Philippines  12.750349  122.731210      2
# 498      Botswana -23.168178   24.592874      2
# 499        marlal  26.492533   92.330879      1
#
# [500 rows x 4 columns]

# %%
dfMap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    500 non-null    object
#  1   Latitude   500 non-null    float64
#  2   Longitude  500 non-null    float64
#  3   sales      500 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.8+ KB

# %%
import folium
from branca.colormap import linear

color_scale = linear.PuRd_09.scale(dfMap['sales'].min(), dfMap['sales'].max())
color_scale.caption = 'Car Sales'
world_map = folium.Map(location=[20, 0], zoom_start=2)

for idx, row in dfMap.iterrows():
    folium.CircleMarker(location=[row['Latitude'], row['Longitude']], 
                        radius=5, 
                        color=color_scale(row['sales']), 
                        fill=True, 
                        fill_color=color_scale(row['sales']), 
                        fill_opacity=0.6,
                        popup=f"{row['country']}: {row['sales']} car sales").add_to(world_map)

color_scale.add_to(world_map)

world_map.save('car_sales_map.html')

# %%
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a13b47ac9754f740ccc77d79ca64b71 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a13b47ac9754f740ccc77d79ca64b71&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a13b47ac9754f740ccc77d79ca64b71 = L.map(
#                 &quot;map_3a13b47ac9754f740ccc77d79ca64b71&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82f05c167205561bbe1e9ed6c642e77e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_82f05c167205561bbe1e9ed6c642e77e.addTo(map_3a13b47ac9754f740ccc77d79ca64b71);
#
#
#             var circle_marker_2e2ee729ebb60cbde439088503858912 = L.circleMarker(
#                 [42.6073975, 25.4856617],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#dcc9e3ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#dcc9e3ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3a13b47ac9754f740ccc77d79ca64b71);
#
#
#         var popup_eb83ec13d59609f62b3e7ad8e0b2f9cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1ed1e7ee2327323a4007c10fc1b42db = $(`&lt;div id=&quot;html_e1ed1e7ee2327323a4007c10fc1b42db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bulgaria: 2 car sales&lt;/div&gt;`)[0];
#                 popup_eb83ec13d59609f62b3e7ad8e0b2f9cd.setContent(html_e1ed1e7ee2327323a4007c10fc1b42db);
#
#
#
#         circle_marker_2e2ee729ebb60cbde439088503858912.bindPopup(popup_eb83ec13d59609f62b3e7ad8e0b2f9cd)
#         ;
#
#
#
#
#             var circle_marker_5ca63b0fd7f0b905fb006f63409204f9 = L.circleMarker(
#                 [17.1204943, -88.6859028],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ce8bc3ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ce8bc3ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3a13b47ac9754f740ccc77d79ca64b71);
#
#
#         var popup_1e47a2452140e56e9e5fa6e50b60ad65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8813ea5d826958834240f17782809989 = $(`&lt;div id=&quot;html_8813ea5d826958834240f17782809989&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Belize: 3 car sales&lt;/div&gt;`)[0];
#                 popup_1e47a2452140e56e9e5fa6e50b60ad65.setContent(html_8813ea5d826958834240f17782809989);
#
#
#
#         circle_marker_5ca63b0fd7f0b905fb006f63409204f9.bindPopup(popup_1e47a2452140e56e9e5fa6e50b60ad65)
#         ;
#
#
#
#
#             var circle_marker_7fc0e34bd7aee8f5614454bd5fc8316e = L.circleMarker(
#                 [28.0000272, 2.9999825],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#b90a4eff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#b90a4eff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3a13b47ac9754f740ccc77d79ca64b71);
#
#
#         var popup_a52a7783aeb5a2446b30b25ec81e4fef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3b0bd5c27b1501f211b1056867b3bba = $(`&lt;div id=&quot;html_c3b0bd5c27b1501f211b1056867b3bba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Algeria: 5 car sales&lt;/div&gt;`)[0];
#                 popup_a52a7783aeb5a2446b30b25ec81e4fef.setContent(html_c3b0bd5c27b1501f211b1056867b3bba);
#
#
#
#         circle_marker_7fc0e34bd7aee8f5614454bd5fc8316e.bindPopup(popup_a52a7783aeb5a2446b30b25ec81e4fef)
#         ;
#
#
#
#
#             var circle_marker_a879ca071907de3a6975ecff7db0657a = L.circleMarker(
#                 [-19.99697155, -157.78587140620786],
#                 {&quot;bu

# %%
corr_matrix = df[['credit card debt', 'car purchase amount']].corr()
plt.figure(figsize=(5, 5))
sns.heatmap(corr_matrix, annot=True, cmap='BuPu', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
corr_matrix = df[['credit card debt', 'car purchase amount', 'annual Salary', 'net worth', 'age']].corr()
plt.figure(figsize=(5, 5))
sns.heatmap(corr_matrix, annot=True, cmap='BuPu', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
def remove_outliers(df, exclude_columns=None):
    df_filtered = df.copy()
    if exclude_columns is None:
        exclude_columns = []
    
    for col in df_filtered.select_dtypes(include=np.number).columns:
        if col in exclude_columns:
            continue
        
        q1 = df_filtered[col].quantile(0.25)
        q3 = df_filtered[col].quantile(0.75)
        iqr = q3 - q1
        lb = q1 - 1.5 * iqr
        ub = q3 + 1.5 * iqr
        df_filtered = df_filtered[(df_filtered[col] >= lb) & (df_filtered[col] <= ub)]
    
    return df_filtered

dfNoOutliers = remove_outliers(df, exclude_columns=['annual Salary'])
dfNoOutliers
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# 5       Carla Hester                                 mi@Aliquamerat.edu
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#          country  gender        age  annual Salary  credit card debt  \
# 0       Bulgaria       0  41.851720    62812.09301      11609.380910
# 1         Belize       0  40.870623    66646.89292       9572.957136
# 2        Algeria       1  43.152897    53798.55112      11160.355060
# 4         Brazil       1  57.313749    59729.15130       5358.712177
# 5        Liberia       1  56.824893    68499.85162      14179.472440
# ..           ...     ...        ...            ...               ...
# 495        Nepal       0  41.462515    71942.40291       6995.902524
# 496     Zimbabwe       1  37.642000    56039.49793      12301.456790
# 497  Philippines       1  53.943497    68888.77805      10611.606860
# 498     Botswana       1  59.160509    49811.99062      14013.034510
# 499       marlal       1  46.731152    61370.67766       9391.341628
#
#        net worth  car purchase amount country_code continent  \
# 0    238961.2505          35321.45877           BG        EU
# 1    530973.9078          45115.52566           BZ        NA
# 2    638467.1773          42925.70921           DZ        AF
# 4    560304.0671          55915.46248           BR        SA
# 5    428485.3604          56611.99784           LR        AF
# ..           ...                  ...          ...       ...
# 495  541670.1016          48901.44342           NP        AS
# 496  360419.0988          31491.41457           ZW        AF
# 497  764531.3203          64147.28888           PH        AS
# 498  337826.6382          45442.15353           BW        AF
# 499  462946.4924          45107.22566      Unknown   Unknown
#
#                           Coordinates   Latitude   Longitude
# 0            (42.6073975, 25.4856617)  42.607397   25.485662
# 1           (17.1204943, -88.6859028)  17.120494  -88.685903
# 2             (28.0000272, 2.9999825)  28.000027    2.999983
# 4                (-10.3333333, -53.2) -10.333333  -53.200000
# 5             (5.7499721, -9.3658524)   5.749972   -9.365852
# ..                                ...        ...         ...
# 495          (28.3780464, 83.9999901)  28.378046   83.999990
# 496         (-18.4554963, 29.7468414) -18.455496   29.746841
# 497         (12.7503486, 122.7312101)  12.750349  122.731210
# 498         (-23.1681782, 24.5928742) -23.168178   24.592874
# 499  (26.49253305, 92.33087891709363)  26.492533   92.330879
#
# [447 rows x 14 columns]

# %%
dfNoOutliers = dfNoOutliers[['age', 'annual Salary', 'net worth', 'car purchase amount']]
dfNoOutliers
# Out:
#            age  annual Salary    net worth  car purchase amount
# 0    41.851720    62812.09301  238961.2505          35321.45877
# 1    40.870623    66646.89292  530973.9078          45115.52566
# 2    43.152897    53798.55112  638467.1773          42925.70921
# 4    57.313749    59729.15130  560304.0671          55915.46248
# 5    56.824893    68499.85162  428485.3604          56611.99784
# ..         ...            ...          ...                  ...
# 495  41.462515    71942.40291  541670.1016          48901.44342
# 496  37.642000    56039.49793  360419.0988          31491.41457
# 497  53.943497    68888.77805  764531.3203          64147.28888
# 498  59.160509    49811.99062  337826.6382          45442.15353
# 499  46.731152    61370.67766  462946.4924          45107.22566
#
# [447 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
y = dfNoOutliers['car purchase amount']
X = dfNoOutliers.drop('car purchase amount', axis=1)

X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %%
print("Training feature set size:",X_train.shape)
print("Test feature set size:",X_test.shape)
print("Training label set size:",Y_train.shape)
print("Test label set size:",Y_test.shape)
# Out:
# Training feature set size: (312, 3)
# Test feature set size: (135, 3)
# Training label set size: (312,)
# Test label set size: (135,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
lm = LinearRegression()
lm.fit(X_train, Y_train)
trainPred = lm.predict(X_train)
predictions = lm.predict(X_test)

# %%
print("R-squared for training:",(r2_score(Y_train,trainPred)))
print("Mean square error (MSE) for training:", mean_squared_error(Y_train,trainPred))

print("R-squared for testing:",(r2_score(Y_test,predictions)))
print("Mean square error (MSE) for testing:", mean_squared_error(Y_test,predictions))
# Out:
# R-squared for training: 0.9999999785419117
# Mean square error (MSE) for training: 2.193773850805165
# R-squared for testing: 0.9999999781224957
# Mean square error (MSE) for testing: 2.13066501683881

# %%
sns.scatterplot(x=Y_train, y=trainPred)
sns.lineplot(x=Y_train, y=Y_train, color="red", linestyle="dashed")
plt.show()

# %%
sns.scatterplot(x=Y_test, y=predictions)
sns.lineplot(x=Y_test, y=Y_test, color="red", linestyle="dashed")
plt.show()
